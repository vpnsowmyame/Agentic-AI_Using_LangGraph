# %%
### Pydantic Data Validation
from langgraph.graph import StateGraph,START,END
from pydantic import BaseModel

# %%
class State(BaseModel):
     name:str

# %%
## node function
def example_node(state:State):
    return {"name":"Hello"}

# %%
## stateGraph\n",
builder=StateGraph(State)
builder.add_node("example_node",example_node)
builder.add_edge(START,"example_node")
builder.add_edge("example_node",END)
graph=builder.compile()

# %%
graph.invoke({"name":123})
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 graph.invoke({"name":123})
#
# File c:\Users\Win 11\Desktop\Agentic AI Workspace\env\Lib\site-packages\langgraph\pregel\main.py:3068, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3065 chunks: list[dict[str, Any] | Any] = []
#    3066 interrupts: list[Interrupt] = []
# -> 3068 for chunk in self.stream(
#    3069     input,
#    3070     config,
#    3071     context=context,
#    3072     stream_mode=["updates", "values"]
#    3073     if stream_mode == "values"
#    3074     else stream_mode,
#    3075     print_mode=print_mode,
#    3076     output_keys=output_keys,
#    3077     interrupt_before=interrupt_before,
#    3078     interrupt_after=interrupt_after,
#    3079     durability=durability,
#    3080     **kwargs,
#    3081 ):
#    3082     if stream_mode == "values":
#    3083         if len(chunk) == 2:
#
# File c:\Users\Win 11\Desktop\Agentic AI Workspace\env\Lib\site-packages\langgraph\pregel\main.py:2654, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2647             return waiter
#    2649 # Similarly to Bulk Synchronous Parallel / Pregel model
#    2650 # computation proceeds in steps, while there are channel updates.
#    2651 # Channel updates from step N are only visible in step N+1
#    2652 # channels are guaranteed to be immutable for the duration of the step,
#    2653 # with channel updates applied only at the transition between steps.
# -> 2654 while loop.tick():
#    2655     for task in loop.match_cached_writes():
#    2656         loop.output_writes(task.id, task.writes, cached=True)
#
# File c:\Users\Win 11\Desktop\Agentic AI Workspace\env\Lib\site-packages\langgraph\pregel\_loop.py:457, in PregelLoop.tick(self)
#     454     return False
#     456 # prepare next tasks
# --> 457 self.tasks = prepare_next_tasks(
#     458     self.checkpoint,
#     459     self.checkpoint_pending_writes,
#     460     self.nodes,
#     461     self.channels,
#     462     self.managed,
#     463     self.config,
#     464     self.step,
#     465     self.stop,
#     466     for_execution=True,
#     467     manager=self.manager,
#     468     store=self.store,
#     469     checkpointer=self.checkpointer,
#     470     trigger_to_nodes=self.trigger_to_nodes,
#     471     updated_channels=self.updated_channels,
#     472     retry_policy=self.retry_policy,
#     473     cache_policy=self.cache_policy,
#     474 )
#     476 # produce debug output
#     477 if self._checkpointer_put_after_previous is not None:
#
# File c:\Users\Win 11\Desktop\Agentic AI Workspace\env\Lib\site-packages\langgraph\pregel\_algo.py:467, in prepare_next_tasks(checkpoint, pending_writes, processes, channels, managed, config, step, stop, for_execution, store, checkpointer, manager, trigger_to_nodes, updated_channels, retry_policy, cache_policy)
#     464 # Check if any processes should be run in next step
#     465 # If so, prepare the values to be passed to them
#     466 for name in candidate_nodes:
# --> 467     if task := prepare_single_task(
#     468         (PULL, name),
#     469         None,
#     470         checkpoint=checkpoint,
#     471         checkpoint_id_bytes=checkpoint_id_bytes,
#     472         checkpoint_null_version=null_version,
#     473         pending_writes=pending_writes,
#     474         processes=processes,
#     475         channels=channels,
#     476         managed=managed,
#     477         config=config,
#     478         step=step,
#     479         stop=stop,
#     480         for_execution=for_execution,
#     481         store=store,
#     482         checkpointer=checkpointer,
#     483         manager=manager,
#     484         input_cache=input_cache,
#     485         cache_policy=cache_policy,
#     486         retry_policy=retry_policy,
#     487     ):
#     488         tasks.append(task)
#     489 return {t.id: t for t in tasks}
#
# File c:\Users\Win 11\Desktop\Agentic AI Workspace\env\Lib\site-packages\langgraph\pregel\_algo.py:807, in prepare_single_task(task_path, task_id_checksum, checkpoint, checkpoint_id_bytes, checkpoint_null_version, pending_writes, processes, channels, managed, config, step, stop, for_execution, store, checkpointer, manager, input_cache, cache_policy, retry_policy)
#     805 # create task input
#     806 try:
# --> 807     val = _proc_input(
#     808         proc,
#     809         managed,
#     810         channels,
#     811         for_execution=for_execution,
#     812         input_cache=input_cache,
#     813         scratchpad=scratchpad,
#     814     )
#     815     if val is MISSING:
#     816         return
#
# File c:\Users\Win 11\Desktop\Agentic AI Workspace\env\Lib\site-packages\langgraph\pregel\_algo.py:1057, in _proc_input(proc, managed, channels, for_execution, scratchpad, input_cache)
#    1055 # If the process has a mapper, apply it to the value
#    1056 if for_execution and proc.mapper is not None:
# -> 1057     val = proc.mapper(val)
#    1059 # Cache the input value
#    1060 if input_cache is not None:
#
# File c:\Users\Win 11\Desktop\Agentic AI Workspace\env\Lib\site-packages\langgraph\graph\state.py:1239, in _coerce_state(schema, input)
#    1238 def _coerce_state(schema: type[Any], input: dict[str, Any]) -> dict[str, Any]:
# -> 1239     return schema(**input)
#
# File c:\Users\Win 11\Desktop\Agentic AI Workspace\env\Lib\site-packages\pydantic\main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
#     257         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     258         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     259         stacklevel=2,
#     260     )
#
# ValidationError: 1 validation error for State
# name
#   Input should be a valid string [type=string_type, input_value=123, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Before task with name 'example_node' and path '('__pregel_pull', 'example_node')'
